# %% [markdown]
# #### Part 1
# #### Task 2(a): Incorrect updation of the pointers.
# #### Task 2(c): Won't maintain the circular structure.
# #### Task 2(d): You are not mainting or updating any size attribute.
# #### Task 2(f): Wrong pointer update at the end, also you neither initialized nor maintained or updated any size attribute.

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# **Assignment Part 1: Doubly Linked List**

# %% [markdown]
# For Assignment Part 1, you should write your full code in the following cells along with your driver codes on your own.

# %%
#Assignment Part 1
class Patient:#node
  #write a constructor
  def __init__(self,id=0,name=None,age=0,blood_group=None):
    self.id=id
    self.name=name
    self.age=age
    self.blood_group=blood_group
    self.next = None
    self.prev = None

# %%
class WRM:
  #write a constructor
  def __init__(self):
    self.head = Patient()
    self.head.next = self.head
    self.head.prev - self.head



  def registerPatient(self,id, name, age, bloodgroup):
    #To Do
     new_patient = Patient(id, name, age, bloodgroup)
     new_node = Patient(new_patient)
     if self.head.next is None:
      new_node.next = new_node.prev = new_node
      self.head.next = new_node
     else:
      last_node = self.head.next.prev
      new_node.next = self.head.next
      new_node.prev = last_node
      self.head.next.prev = new_node
      last_node.next = new_node
     print("Success" )

  def servePatient(self):
    #To Do
     t= self.head.next
     if t == self.head :
      print("No patients in the waiting room.")
     else:
       print(t.name,"is served" )

     if t.next!=self.head:
       t.next.prev =t.prev
       t.prev.next = t.next
     else:
       self.head.next =self.head
       self.head.prev = self.head

  def showAllPatient(self):
    #To Do

         t = self.head.next

         if self.head.next != self.head:
            while t!= self.head:
                if t.next != self.head:
                    print(t.name,end='-->')
                else:
                    print(t.name)
                t = t.next
         else:
            print('No Patients')

         t = self.head.next
         if self.head.next != self.head:
            while t != self.head:
                print(f'Name:{t.name}\nAge:{t.age}\nID:{t.id}\nBlood Group:{t.blood_group}')
                t = t.next



  def canDoctorGoHome(self):
    #To Do
    return self.size == 0


  def cancelAll(self):
    #To Do
    self.head.next = None
    self.size = 0
    print("All appointments cancelled.")

  def ReverseTheLine(self):
    #To Do
    if self.size <= 1:
      print("Not enough patients in the waiting room to reverse the line.")
      return
    current = self.head.next
    for _ in range(self.size):
      current.next, current.prev = current.prev, current.next
      current = current.prev
    self.head.next = self.head.next.prev
    print("Line reversed successfully.")
Patient= WRM()
print('Press 1 to register patient.\nPress 2 to serve patient.\nPress 3 to show patient details.\nPress 4 to show if the doctor can go home.\nPress 5 to cancel all appointments.\nPress 6 to reverse the serial.\nPress 7 to exit the program.')

while True:
    n = int(input('Please enter a number: '))
    if n == 1:
        name = input('Please Enter Patient Name: ')
        age = int(input("Please Enter Patient's Age: "))
        id = int(input("Please Enter Patient's ID: "))
        BG = input("Please Enter Patient's Blood Group: ")
        Patient.RegisterPatient(name,id,age,BG)
    elif n == 2:
        Patient.ServePatient()
    elif n == 3:
        Patient.ShowAllPatient()
    elif n == 4:
        print(Patient.canDoctorGoHome())
    elif n == 5:
        print(Patient.CancelAll())
    elif n == 6:
        print(Patient.ReverseTheLine())
    elif n == 7:
        break
# Out:
#   File "<tokenize>", line 72
#     = WRM()
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#Write a Tester Code in this cell
print("**Welcome to Waiting Room Management System**")
# Out:
# **Welcome to Waiting Room Management System**

# %% [markdown]
# **Assignment Part 2: Stack**
#
# Linked List based Stack is implemented in the following cell.

# %%
class Node:
  def __init__(self,elem=None,next=None):
    self.elem = elem
    self.next = next

class Stack:
  def __init__(self):
    self.__top = None

  def push(self,elem):
    nn = Node(elem,self.__top)
    self.__top = nn

  def pop(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    e = self.__top
    self.__top = self.__top.next
    e.next = None
    return e.elem

  def peek(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    return self.__top.elem

  def isEmpty(self):
    return self.__top == None

# %%
#You can run this driver code cell to understand the methods of Stack class
st = Stack()
st.push(4)
st.push(3)
st.push(5)
st.push(1)
st.push(9)

print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print(st.isEmpty())
# Out:
# Peeked Element:  9
# Popped Element:  9
# Popped Element:  1
# Popped Element:  5
# Peeked Element:  3
# Popped Element:  3
# Popped Element:  4
# Peeked Element:  None
# Popped Element:  None
# True

# %% [markdown]
# You can print your stack using this code segment

# %%
def print_stack(st):
  if st.isEmpty():
    return
  p = st.pop()
  print('|',p,end=' ')
  if p<10:
    print(' |')
  else:
    print('|')
  #print('------')
  print_stack(st)
  st.push(p)

# st = Stack()
# st.push(4)
# st.push(3)
# st.push(5)
# st.push(1)
# st.push(9)
# print_stack(st)
# print('------')

# %% [markdown]
# Task 1: Diamond Count

# %%
def diamond_count(stack,string):
  #TO DO
   t = 0
   for v in string:
        if v == '<':
            stack.push(v)
        elif v == '>':
            if  stack.isEmpty()!='' and stack.peek() == '<':
                stack.pop()
                t += 1
   return t

print('Test 01')
stack = Stack()
string = '<..><.<..>> '
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')


print('Test 02')
stack = Stack()
string = '<<<..<......<<<<....>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 1
unittest.output_test(returned_value, 1)
print('-----------------------------------------')


print('Test 03')
stack = Stack()
string = '>>><...<<..>>...>...>>>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')
# Out:
# Test 01
# Number of Diamonds: 3
# Accepted
# -----------------------------------------
# Test 02
# Number of Diamonds: 1
# Accepted
# -----------------------------------------
# Test 03
# Number of Diamonds: 3
# Accepted
# -----------------------------------------

# %% [markdown]
# Task 2: Tower of Blocks

# %%
def remove_block(stack, n):
    att = Stack()
    t = 0
    while t < n - 1:
        blk = stack.pop()
        att.push(blk)
        t+= 1
    stack.pop()
    while not att.isEmpty() :
        stack.push(att.pop())

print('Test 01')
st = Stack()
st.push(4)
st.push(19)
st.push(23)
st.push(17)
st.push(5)
print('Stack:')
print_stack(st)
print('------')
remove_block(st,2)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()

print('Test 02')
st = Stack()
st.push(73)
st.push(85)
st.push(15)
st.push(41)
print('Stack:')
print_stack(st)
print('------')
remove_block(st,3)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()
# Out:
# Test 01
# Stack:
# | 5  |
# | 17 |
# | 23 |
# | 19 |
# | 4  |
# ------
# After Removal
# | 5  |
# | 23 |
# | 19 |
# | 4  |
# ------
#
# ...
#
# Test 02
# Stack:
# | 41 |
# | 15 |
# | 85 |
# | 73 |
# ------
# After Removal
# | 41 |
# | 15 |
# | 73 |
# ------
#
# ...

# %% [markdown]
# Task 3: Stack Reverse

# %%
def conditional_reverse(stack):
    result = Stack()
    while not stack.isEmpty():
        elem = stack.pop()
        if  elem != result.peek():
            result.push(elem)
    return result
print('Test 01')
st=Stack()
st.push(10)
st.push(10)
st.push(20)
st.push(20)
st.push(30)
st.push(10)
st.push(50)
print('Stack:')
print_stack(st)
print('------')
reversed_stack=conditional_reverse(st)
print('Conditional Reversed Stack:')
print_stack(reversed_stack) # This stack contains 50, 10, 30, 20, 10 in this order whereas top element should be 10
print('------')
# Out:
# Test 01
# Stack:
# | 50 |
# | 10 |
# | 30 |
# | 20 |
# | 20 |
# | 10 |
# | 10 |
# ------
# Conditional Reversed Stack:
# | 10 |
# | 20 |
# | 30 |
# | 10 |
# | 50 |
# ------
