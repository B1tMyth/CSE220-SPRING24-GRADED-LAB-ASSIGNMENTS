# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# **Assignment Part 1: Doubly Linked List**

# %% [markdown]
# For Assignment Part 1, you should write your full code in the following cells along with your driver codes on your own.

# %%
#Assignment Part 1

class Patient:
  #write a constructor
  def __init__(self,id=None,name=None,age=None,bloodgroup=None):
    self.id=id
    self.name=name
    self.age=age
    self.bloodgroup=bloodgroup
    self.next=None
    self.prev=None

# %%
class WRM:
  #write a constructor
  def __init__(self):
    self.head=Patient()
    self.head.next=self.head

  def registerPatient(self,id, name, age, bloodgroup):
    #To Do
    new=Patient(id,name,age,bloodgroup)
    n=self.head
    while n.next!=self.head:
      n=n.next
    n.next=new
    new.prev=n
    new.next=self.head
    return self.head

  def servePatient(self):
    #To Do
    n=self.head.next
    if n!=self.head:
      print(n.name,"has been served")
      self.head.next=n.next
    else:
      print("Everyone has been served")

  def showAllPatient(self):
    #To Do
    if self.head.next==self.head:
      print("No one is in the list")
    else:
      n=self.head.next
      while n!=self.head:
        print(n.name)
        n=n.next
  def canDoctorGoHome(self):
    #To Do
    n=self.head.next
    count=0
    while n!=self.head:
      count+=1
      n=n.next
    if count==0:
      print("Doctor can go home")
    else:
      print("Doctor cannot go home")

  def cancelAll(self):
    #To Do
    self.head.next=self.head
    self.head.prev=self.head

  def ReverseTheLine(self):
    #To Do
    n=self.head.next
    n2=self.head.next
    count=0
    print("Line has been reversed")
    if n.prev!=None:
      while n.next!=self.head:
        n=n.next
        count+=1
      tail=n
      c2=0
      while n2!=self.head and c2<=count//2:
        id=tail.id
        name=tail.name
        age=tail.age
        bloodgroup=tail.bloodgroup

        tail.id=n2.id
        tail.name=n2.name
        tail.age=n2.age
        tail.bloodgroup=n2.bloodgroup

        n2.id=id
        n2.name=name
        n2.age=age
        n2.bloodgroup=bloodgroup
        n2=n2.next
        tail=tail.prev
        c2+=1
      else:
        print()

# %%
#Write a Tester Code in this cell
print("**Welcome to Waiting Room Management System**")
ref=False
p1=WRM()
while ref!=True:
  print("***Choose Any Option:***\n1.RegeisterPatient()\n2.servePatient()\n3.CancelAll()\n4.CanDoctorGoHome()\n5.ShowAllPatient()\n6.ReverseTheLine()\n7.Exit")
  inp=input("Please choose Any Number:")
  if inp=="1":
    id=input("Plese enter any ID: ")
    name=input("Please enter any Name: ")
    age=input("Please enter any age: ")
    bloodgroup=input("Please enter blood Group: ")
    p1.registerPatient(id,name,age,bloodgroup)
  elif inp=="2":
    p1.servePatient()
  elif inp=="3":
    p1.cancelAll()
  elif inp=="4":
    p1.canDoctorGoHome()
  elif inp=="5":
    p1.showAllPatient()
  elif inp=="6":
    p1.ReverseTheLine()
  elif inp=="7":
    ref=True
  else:
    print("Please enter any valid number")
print()
print()
print()
# Out:
# **Welcome to Waiting Room Management System**
# ***Choose Any Option:***
# 1.RegeisterPatient()
# 2.servePatient()
# 3.CancelAll()
# 4.CanDoctorGoHome()
# 5.ShowAllPatient()
# 6.ReverseTheLine()
# 7.Exit
# Please choose Any Number:1
# Plese enter any ID: 2
# Please enter any Name: s
# Please enter any age: 2
# Please enter blood Group: b
# ***Choose Any Option:***
# 1.RegeisterPatient()
# 2.servePatient()
# 3.CancelAll()
# 4.CanDoctorGoHome()
# 5.ShowAllPatient()
# 6.ReverseTheLine()
# 7.Exit
# Please choose Any Number:5
# s
# ***Choose Any Option:***
# 1.RegeisterPatient()
# 2.servePatient()
# 3.CancelAll()
# 4.CanDoctorGoHome()
# 5.ShowAllPatient()
# 6.ReverseTheLine()
# 7.Exit
# Please choose Any Number:2
# s has been served
# ***Choose Any Option:***
# 1.RegeisterPatient()
# 2.servePatient()
# 3.CancelAll()
# 4.CanDoctorGoHome()
# 5.ShowAllPatient()
# 6.ReverseTheLine()
# 7.Exit
# Please choose Any Number:4
# Doctor can go home
# ***Choose Any Option:***
# 1.RegeisterPatient()
# ...

# %% [markdown]
# **Assignment Part 2: Stack**
#
# Linked List based Stack is implemented in the following cell.

# %%
class Node:
  def __init__(self,elem=None,next=None):
    self.elem = elem
    self.next = next

class Stack:
  def __init__(self):
    self.__top = None

  def push(self,elem):
    nn = Node(elem,self.__top)
    self.__top = nn

  def pop(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    e = self.__top
    self.__top = self.__top.next
    return e.elem

  def peek(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    return self.__top.elem

  def isEmpty(self):
    return self.__top == None

# %%
#You can run this driver code cell to understand the methods of Stack class
st = Stack()
st.push(4)
st.push(3)
st.push(5)
st.push(1)
st.push(9)

print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print(st.isEmpty())
# Out:
# Peeked Element:  9
# Popped Element:  9
# Popped Element:  1
# Popped Element:  5
# Peeked Element:  3
# Popped Element:  3
# Popped Element:  4
# Peeked Element:  None
# Popped Element:  None
# True

# %% [markdown]
# You can print your stack using this code segment

# %%
def print_stack(st):
  if st.isEmpty():
    return
  p = st.pop()
  print('|',p,end=' ')
  if p<10:
    print(' |')
  else:
    print('|')
  #print('------')
  print_stack(st)
  st.push(p)

# st = Stack()
# st.push(4)
# st.push(3)
# st.push(5)
# st.push(1)
# st.push(9)
# print_stack(st)
# print('------')

# %% [markdown]
# Task 1: Diamond Count

# %%
def diamond_count(stack,string):
  #TO DO
  diamonds=0
  for c in string:
    if c=='<':
      stack.push(c)
    elif c=='>'and not stack.isEmpty() and stack.peek()=='<':
      stack.pop()
      diamonds+=1
  return diamonds

print('Test 01')
stack = Stack()
string = '<..><.<..>> '
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')


print('Test 02')
stack = Stack()
string = '<<<..<......<<<<....>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 1
unittest.output_test(returned_value, 1)
print('-----------------------------------------')


print('Test 03')
stack = Stack()
string = '>>><...<<..>>...>...>>>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')
# Out:
# Test 01
# Number of Diamonds: 3
# Accepted
# -----------------------------------------
# Test 02
# Number of Diamonds: 1
# Accepted
# -----------------------------------------
# Test 03
# Number of Diamonds: 3
# Accepted
# -----------------------------------------

# %% [markdown]
# Task 2: Tower of Blocks

# %%
def remove_block(self, n):
  if n <= 0 or self.is_empty():
    return

  temp_stack = Stack()
  count = 0

  while count < n and not self.is_empty():
    temp_stack.push(self.pop())
    count += 1

  temp_stack.pop()

  while not temp_stack.is_empty():
    self.push(temp_stack.pop())

print('Test 01')
st = Stack()
st.push(4)
st.push(19)
st.push(23)
st.push(17)
st.push(5)
print('Stack:')
print_stack(st)
print('------')
st.remove_block(2)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()

print('Test 02')
st = Stack()
st.push(73)
st.push(85)
st.push(15)
st.push(41)
print('Stack:')
print_stack(st)
print('------')
st.remove_block(3)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()
# Out:
# Test 01
# Stack:
# | 5  |
# | 17 |
# | 23 |
# | 19 |
# | 4  |
# ------
# After Removal
# | 5  |
# | 23 |
# | 19 |
# | 4  |
# ------
#
# ...
#
# Test 02
# Stack:
# | 41 |
# | 15 |
# | 85 |
# | 73 |
# ------
# After Removal
# | 41 |
# | 15 |
# | 73 |
# ------
#
# ...

# %% [markdown]
# Task 3: Stack Reverse

# %%
def conditional_reverse(stack):
  #To Do
  reversed=Stack()
  temp=Stack()

  while not stack.isEmpty():
    element=stack.pop()
    if temp.isEmpty() and temp.peek()!=element:
      temp.push(element)
    else:
      while not temp.isEmpty():
         reversed.push(temp.pop())
      reversed.push(element)

  while not temp.isEmpty() and temp.peek()!=element:
     reversed.push(temp.pop())
  return reversed

print('Test 01')
st=Stack()
st.push(10)
st.push(10)
st.push(20)
st.push(20)
st.push(30)
st.push(10)
st.push(50)
print('Stack:')
print_stack(st)
print('------')
reversed_stack=conditional_reverse(st)
print('Conditional Reversed Stack:')
print_stack(reversed_stack) # This stack contains 50, 10, 30, 20, 10 in this order whereas top element should be 10
print('------')
# Out:
# Test 01
# Stack:
# | 50 |
# | 10 |
# | 30 |
# | 20 |
# | 20 |
# | 10 |
# | 10 |
# ------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-be1a220383c4> in <cell line: 31>()
#      29 print_stack(st)
#      30 print('------')
# ---> 31 reversed_stack=conditional_reverse(st)
#      32 print('Conditional Reversed Stack:')
#      33 print_stack(reversed_stack) # This stack contains 50, 10, 30, 20, 10 in this order whereas top element should be 10
#
# <ipython-input-8-be1a220383c4> in conditional_reverse(stack)
#       4   temp=Stack()
#       5
# ----> 6   while not stack.isEmpty():
#       7     element=stack.pop()
#       8     if temp.isEmpty() and temp.peek()!=element:
#
# AttributeError: 'Stack' object has no attribute 'isEmpty'
