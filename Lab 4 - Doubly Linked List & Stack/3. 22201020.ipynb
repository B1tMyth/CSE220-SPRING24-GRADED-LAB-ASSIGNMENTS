# %% [markdown]
# #### Plagiarized with ID: 22201100.

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# **Assignment Part 1: Doubly Linked List**

# %% [markdown]
# For Assignment Part 1, you should write your full code in the following cells along with your driver codes on your own.

# %%
#Assignment Part 1

class Patient:
  def __init__(self,id,name,age,bloodgroup,prev,next):
    self.id = id
    self.name = name
    self.age = age
    self.bloodgroup = bloodgroup
    self.prev= prev
    self.next= next

# %%
class WRM:
  def __init__(self):
    self.head = Patient(None,None,None,None,None,None)
    self.head.prev = self.head
    self.head.next = self.head
  def registerPatient(self,id, name, age, bloodgroup):
    new_patient = Patient(id, name, age, bloodgroup,self.head.prev,self.head)
    self.head.prev.next = new_patient
    self.head.prev = new_patient

  def servePatient(self):
    x = self.head.next
    self.head.next = self.head.next.next
    self.head.next.prev = self.head

  def showAllPatient(self):
    temp = self.head
    while True:
      if temp.id!=None:
        print(f"Name: {temp.name}\nID:{temp.id}\nAge:{temp.age}\nBloodgroup{temp.bloodgroup}")
        print()
      if temp.next==self.head:
        break
      temp = temp.next
  def canDoctorGoHome(self):
    temp = self.head
    if temp.next!=self.head:
      return False
    return True
  def cancelAll(self):
    x = self.head.next
    self.head.next = self.head
    self.head.prev = self.head
    x = None
  def ReverseTheLine(self):
      temp = self.head
      while True:
        temp.next,temp.prev = temp.prev,temp.next
        if temp.next == self.head:
          break
        temp = temp.next

hospital = WRM()
hospital.registerPatient(1,"Nafi",17,"A+")
hospital.registerPatient(2,"kafi",15,"A-")
hospital.registerPatient(3,"Pafi",18,"O+")
hospital.registerPatient(4,"Dafi",19,"O+")
hospital.registerPatient(5,"Bafi",10,"O-")
hospital.registerPatient(6,"Gafi",13,"AB+")
hospital.registerPatient(7,"Vafi",15,"AB-")
hospital.registerPatient(8,"Bufi",27,"A+")
hospital.registerPatient(9,"Tafi",11,"A-")
hospital.registerPatient(10,"Gefi",20,"A+")
hospital.showAllPatient()
print(hospital.canDoctorGoHome())
print()
hospital.servePatient()
hospital.ReverseTheLine()
hospital.showAllPatient()
print()
hospital.cancelAll()
hospital.showAllPatient()
print(hospital.canDoctorGoHome())
# Out:
# Name: Nafi
# ID:1
# Age:17
# BloodgroupA+
#
# Name: kafi
# ID:2
# Age:15
# BloodgroupA-
#
# Name: Pafi
# ID:3
# Age:18
# BloodgroupO+
#
# Name: Dafi
# ID:4
# Age:19
# BloodgroupO+
#
# Name: Bafi
# ID:5
# Age:10
# BloodgroupO-
#
# Name: Gafi
# ID:6
# Age:13
# BloodgroupAB+
#
# Name: Vafi
# ID:7
# Age:15
# BloodgroupAB-
#
# Name: Bufi
# ID:8
# Age:27
# BloodgroupA+
#
# Name: Tafi
# ID:9
# Age:11
# BloodgroupA-
#
# Name: Gefi
# ID:10
# Age:20
# BloodgroupA+
#
# False
#
# Name: Gefi
# ID:10
# Age:20
# BloodgroupA+
#
# Name: Tafi
# ID:9
# Age:11
# BloodgroupA-
#
# Name: Bufi
# ID:8
# Age:27
# BloodgroupA+
#
# Name: Vafi
# ID:7
# Age:15
# BloodgroupAB-
#
# Name: Gafi
# ID:6
# Age:13
# BloodgroupAB+
#
# Name: Bafi
# ID:5
# Age:10
# BloodgroupO-
#
# Name: Dafi
# ID:4
# Age:19
# BloodgroupO+
#
# Name: Pafi
# ID:3
# Age:18
# BloodgroupO+
#
# Name: kafi
# ID:2
# Age:15
# BloodgroupA-
#
#
# True

# %%
#Write a Tester Code in this cell
print("**Welcome to Waiting Room Management System**")
# Out:
# **Welcome to Waiting Room Management System**

# %% [markdown]
# **Assignment Part 2: Stack**
#
# Linked List based Stack is implemented in the following cell.

# %%
class Node:
  def __init__(self,elem=None,next=None):
    self.elem = elem
    self.next = next

class Stack:
  def __init__(self):
    self.__top = None

  def push(self,elem):
    nn = Node(elem,self.__top)
    self.__top = nn

  def pop(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    e = self.__top
    self.__top = self.__top.next
    return e.elem

  def peek(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    return self.__top.elem

  def isEmpty(self):
    return self.__top == None

# %%
#You can run this driver code cell to understand the methods of Stack class
st = Stack()
st.push(4)
st.push(3)
st.push(5)
st.push(1)
st.push(9)

print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print(st.isEmpty())
# Out:
# Peeked Element:  9
# Popped Element:  9
# Popped Element:  1
# Popped Element:  5
# Peeked Element:  3
# Popped Element:  3
# Popped Element:  4
# Peeked Element:  None
# Popped Element:  None
# True

# %% [markdown]
# You can print your stack using this code segment

# %%
def print_stack(st):
  if st.isEmpty():
    return
  p = st.pop()
  print('|',p,end=' ')
  if p<10:
    print(' |')
  else:
    print('|')
  #print('------')
  print_stack(st)
  st.push(p)

# st = Stack()
# st.push(4)
# st.push(3)
# st.push(5)
# st.push(1)
# st.push(9)
# print_stack(st)
# print('------')

# %% [markdown]
# Task 1: Diamond Count

# %%
def diamond_count(stack,string):
  diamond_count = 0
  for i in string:
    if i == "<":
      stack.push(i)
    elif i == ">":
      x = stack.peek()
      if x=="<":
        diamond_count+=1
        stack.pop()
  return diamond_count

print('Test 01')
stack = Stack()
string = '<..><.<..>> '
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')


print('Test 02')
stack = Stack()
string = '<<<..<......<<<<....>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 1
unittest.output_test(returned_value, 1)
print('-----------------------------------------')


print('Test 03')
stack = Stack()
string = '>>><...<<..>>...>...>>>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')
# Out:
# Test 01
# Number of Diamonds: 3
# Accepted
# -----------------------------------------
# Test 02
# Number of Diamonds: 1
# Accepted
# -----------------------------------------
# Test 03
# Number of Diamonds: 3
# Accepted
# -----------------------------------------

# %% [markdown]
# Task 2: Tower of Blocks

# %%
def remove_block(stack, n):
  new_stack = Stack()
  for i in range(1,n+1):
    if i==n:
      elem = stack.pop()
      elem = None
    else:
      elem = stack.pop()
      new_stack.push(elem)
  while new_stack.peek()!=None:
    elem = new_stack.pop()
    stack.push(elem)
  return stack


print('Test 01')
st = Stack()
st.push(4)
st.push(19)
st.push(23)
st.push(17)
st.push(5)
print('Stack:')
print_stack(st)
print('------')
remove_block(st,2)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()

print('Test 02')
st = Stack()
st.push(73)
st.push(85)
st.push(15)
st.push(41)
print('Stack:')
print_stack(st)
print('------')
remove_block(st,3)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()
# Out:
# Test 01
# Stack:
# | 5  |
# | 17 |
# | 23 |
# | 19 |
# | 4  |
# ------
# After Removal
# | 5  |
# | 23 |
# | 19 |
# | 4  |
# ------
#
# ...
#
# Test 02
# Stack:
# | 41 |
# | 15 |
# | 85 |
# | 73 |
# ------
# After Removal
# | 41 |
# | 15 |
# | 73 |
# ------
#
# ...

# %% [markdown]
# Task 3: Stack Reverse

# %%
def conditional_reverse(stack):
  reversed_stack = Stack()
  consecutive_number = None
  while stack.peek()!=None:
    current_elem = stack.pop()
    if current_elem != consecutive_number:
      reversed_stack.push(current_elem)
      consecutive_number = current_elem
  return reversed_stack



print('Test 01')
st=Stack()
st.push(10)
st.push(10)
st.push(20)
st.push(20)
st.push(30)
st.push(10)
st.push(50)
print('Stack:')
print_stack(st)
print('------')
reversed_stack=conditional_reverse(st)
print('Conditional Reversed Stack:')
print_stack(reversed_stack) # This stack contains 50, 10, 30, 20, 10 in this order whereas top element should be 10
print('------')
# Out:
# Test 01
# Stack:
# | 50 |
# | 10 |
# | 30 |
# | 20 |
# | 20 |
# | 10 |
# | 10 |
# ------
# Conditional Reversed Stack:
# | 10 |
# | 20 |
# | 30 |
# | 10 |
# | 50 |
# ------
